# %% [markdown]
# <a href="https://colab.research.google.com/github/desnug/Audio_alarm_classification/blob/main/alarm_classification_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Audio Alarm Classification For Deaf and Hard Hearing

# %% [markdown]
# Project Thesis by : Devis Styo Nugroho

# %% [markdown]
# ## Setup
#
# Import necessary modules and dependencies. and install some packages that we needed

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 5.7 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
import numpy as np
import os
import requests
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("drive/MyDrive/data/dataset-alarm-folder")

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/data/dataset-alarm-folder"

# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# !ls
# Out:
# alarm-dataset.zip  dataset  kaggle.json

# %%
# !kaggle datasets download -d devisdesnug/alarm-dataset
# Out:
# Downloading alarm-dataset.zip to /content/drive/MyDrive/data/dataset-alarm-folder
#  89% 70.0M/78.4M [00:01<00:00, 69.2MB/s]
# 100% 78.4M/78.4M [00:01<00:00, 67.0MB/s]

# %%
# !unzip alarm-dataset.zip
# Out:
# Archive:  alarm-dataset.zip
#   inflating: dataset/alarm_danger/1_danger_alarm_0.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_1.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_10.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_100.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_101.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_102.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_103.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_104.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_105.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_106.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_107.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_108.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_109.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_11.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_110.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_111.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_112.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_113.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_114.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_115.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_116.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_117.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_118.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_119.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_12.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_120.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_121.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_122.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_123.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_124.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_125.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_126.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_127.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_128.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_129.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_13.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_130.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_131.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_132.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_133.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_134.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_135.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_136.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_137.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_138.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_139.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_14.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_140.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_141.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_142.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_143.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_144.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_145.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_146.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_147.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_148.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_149.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_15.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_150.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_151.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_152.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_153.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_154.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_155.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_156.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_157.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_158.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_159.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_16.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_160.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_161.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_162.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_163.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_164.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_165.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_166.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_167.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_168.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_169.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_17.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_170.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_171.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_172.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_173.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_174.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_175.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_176.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_177.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_178.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_179.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_18.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_180.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_181.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_182.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_183.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_184.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_185.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_186.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_187.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_188.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_189.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_19.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_190.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_191.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_192.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_193.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_194.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_195.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_196.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_197.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_198.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_199.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_2.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_20.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_200.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_201.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_202.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_203.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_204.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_205.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_206.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_207.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_208.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_209.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_21.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_210.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_211.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_212.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_213.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_214.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_215.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_216.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_217.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_218.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_219.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_22.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_220.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_221.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_222.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_223.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_224.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_225.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_226.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_227.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_228.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_229.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_23.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_230.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_231.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_232.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_233.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_234.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_235.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_236.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_237.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_238.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_239.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_24.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_240.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_241.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_242.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_243.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_244.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_245.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_246.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_247.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_248.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_249.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_25.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_250.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_251.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_252.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_253.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_254.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_255.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_256.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_257.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_258.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_259.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_26.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_260.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_261.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_262.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_263.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_264.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_265.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_266.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_267.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_268.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_269.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_27.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_270.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_271.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_272.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_273.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_274.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_275.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_276.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_277.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_278.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_279.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_28.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_280.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_281.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_282.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_283.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_284.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_285.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_286.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_287.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_288.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_289.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_29.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_290.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_291.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_292.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_293.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_294.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_295.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_296.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_297.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_298.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_299.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_3.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_30.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_300.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_301.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_302.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_303.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_304.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_305.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_306.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_307.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_308.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_309.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_31.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_310.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_311.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_312.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_313.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_314.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_315.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_316.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_317.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_318.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_319.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_32.wav
#   inflating: dataset/alarm_danger/1_danger_alarm_320.wav
#   inflating: dataset/alarm_danger/1_danger_alarm
wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_556.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_557.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_558.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_559.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_56.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_560.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_561.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_562.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_563.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_564.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_565.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_566.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_567.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_568.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_569.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_57.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_570.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_571.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_572.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_573.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_574.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_575.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_576.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_577.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_578.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_579.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_58.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_580.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_581.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_582.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_583.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_584.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_585.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_586.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_587.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_588.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_589.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_59.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_590.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_591.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_592.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_593.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_594.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_595.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_596.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_597.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_598.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_599.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_6.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_60.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_600.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_61.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_62.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_63.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_64.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_65.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_66.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_67.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_68.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_69.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_7.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_70.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_71.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_72.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_73.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_74.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_75.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_76.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_77.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_78.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_79.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_8.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_80.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_81.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_82.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_83.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_84.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_85.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_86.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_87.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_88.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_89.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_9.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_90.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_91.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_92.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_93.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_94.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_95.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_96.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_97.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_98.wav
#   inflating: dataset/alarm_tsunami/5_tsunami_alarm_99.wav

# %% [markdown]
# ## Import Alarm Dataset
#
# alarm dataset contain 3000 file data in 1 second, Sample Rate 16Khz,

# %%
DATASET_PATH = 'dataset'

data_dir = pathlib.Path(DATASET_PATH)

# %% [markdown]
# The dataset's audio clips are stored in five folders corresponding to each *audio alarm: 'alarm_danger',  'alarm_fire',  'alarm_gas',  'non_alarm' and 'alarm_tsunami'* :

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['alarm_danger' 'alarm_fire' 'alarm_gas' 'alarm_non' 'alarm_tsunami']

# %% [markdown]
# Extract the audio clips into a list called `filenames`, and shuffle it:

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 3000
# Number of examples per label: 600
# Example file tensor: tf.Tensor(b'dataset/alarm_gas/3_gas_alarm_187.wav', shape=(), dtype=string)

# %% [markdown]
# Split `filenames` into training, validation and test sets using a 80:10:10 ratio, respectively:

# %%
train_files = filenames[:2400]
val_files = filenames[2400: 2400 + 300]
test_files = filenames[-300:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 2400
# Validation set size 300
# Test set size 300

# %% [markdown]
# ## Read the audio files and their labels

# %% [markdown]
# In this section you will preprocess the dataset, creating decoded tensors for the waveforms and the corresponding labels. Note that:
#
# - Each WAV file contains time-series data with a set number of samples per second.
# - Each sample represents the <a href="https://en.wikipedia.org/wiki/Amplitude" class="external">amplitude</a> of the audio signal at that specific time.
# - In a <a href="https://en.wikipedia.org/wiki/Audio_bit_depth" class="external">16-bit</a> system, the amplitude values range from -32,768 to 32,767.
# - The <a href="https://en.wikipedia.org/wiki/Sampling_(signal_processing)#Audio_sampling" class="external">sample rate</a> for this dataset is 16kHz.
#
# The shape of the tensor returned by `tf.audio.decode_wav` is `[samples, channels]`, where `channels` is `1` for mono or `2` for stereo. The mini Speech Commands dataset only contains mono recordings.

# %%
test_file = tf.io.read_file(DATASET_PATH+'/alarm_danger/1_danger_alarm_101.wav')
test_audio, _ = tf.audio.decode_wav(contents=test_file)
test_audio.shape
# Out:
# TensorShape([16000, 1])

# %% [markdown]
# Now, let's define a function that preprocesses the dataset's raw WAV audio files into audio tensors:

# %%
def decode_audio(audio_binary):
  # Decode WAV-encoded audio files to `float32` tensors, normalized
  # to the [-1.0, 1.0] range. Return `float32` audio and a sample rate.
  audio, _ = tf.audio.decode_wav(contents=audio_binary)
  # Since all the data is single channel (mono), drop the `channels`
  # axis from the array.
  return tf.squeeze(audio, axis=-1)

# %% [markdown]
# Define a function that creates labels using the parent directories for each file:
#
# - Split the file paths into `tf.RaggedTensor`s (tensors with ragged dimensions—with slices that may have different lengths).

# %%
def get_label(file_path):
  parts = tf.strings.split(
      input=file_path,
      sep=os.path.sep)
  # Note: You'll use indexing here instead of tuple unpacking to enable this
  # to work in a TensorFlow graph.
  return parts[-2]

# %% [markdown]
# Define another helper function—`get_waveform_and_label`—that puts it all together:
#
# - The input is the WAV audio filename.
# - The output is a tuple containing the audio and label tensors ready for supervised learning.

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %% [markdown]
# Build the training set to extract the audio-label pairs:
#
# - Create a `tf.data.Dataset` with `Dataset.from_tensor_slices` and `Dataset.map`, using `get_waveform_and_label` defined earlier.
#
# You'll build the validation and test sets using a similar procedure later on.

# %%
AUTOTUNE = tf.data.AUTOTUNE

files_ds = tf.data.Dataset.from_tensor_slices(train_files)

waveform_ds = files_ds.map(
    map_func=get_waveform_and_label,
    num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's plot a few audio waveforms:

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))

for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %% [markdown]
# ## Convert waveforms to spectrograms
#
# The waveforms in the dataset are represented in the time domain. Next, you'll transform the waveforms from the time-domain signals into the time-frequency-domain signals by computing the <a href="https://en.wikipedia.org/wiki/Short-time_Fourier_transform" class="external">short-time Fourier transform (STFT)</a> to convert the waveforms to as <a href="https://en.wikipedia.org/wiki/Spectrogram" clas="external">spectrograms</a>, which show frequency changes over time and can be represented as 2D images. You will feed the spectrogram images into your neural network to train the model.
#
# A Fourier transform (`tf.signal.fft`) converts a signal to its component frequencies, but loses all time information. In comparison, STFT (`tf.signal.stft`) splits the signal into windows of time and runs a Fourier transform on each window, preserving some time information, and returning a 2D tensor that you can run standard convolutions on.
#
# Create a utility function for converting waveforms to spectrograms:
#
# - The waveforms need to be of the same length, so that when you convert them to spectrograms, the results have similar dimensions. This can be done by simply zero-padding the audio clips that are shorter than one second (using `tf.zeros`).
# - When calling `tf.signal.stft`, choose the `frame_length` and `frame_step` parameters such that the generated spectrogram "image" is almost square. For more information on the STFT parameters choice, refer to <a href="https://www.coursera.org/lecture/audio-signal-processing/stft-2-tjEQe" class="external">this Coursera video</a> on audio signal processing and STFT.
# - The STFT produces an array of complex numbers representing magnitude and phase. However, in this tutorial you'll only use the magnitude, which you can derive by applying `tf.abs` on the output of `tf.signal.stft`.

# %%
def get_spectrogram(waveform):
  # Zero-padding for an audio waveform with less than 16,000 samples.
  input_len = 16000
  waveform = waveform[:input_len]
  zero_padding = tf.zeros(
      [16000] - tf.shape(waveform),
      dtype=tf.float32)
  # Cast the waveform tensors' dtype to float32.
  waveform = tf.cast(waveform, dtype=tf.float32)
  # Concatenate the waveform with `zero_padding`, which ensures all audio
  # clips are of the same length.
  equal_length = tf.concat([waveform, zero_padding], 0)
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %% [markdown]
# Next, start exploring the data. Print the shapes of one example's tensorized waveform and the corresponding spectrogram, and play the original audio:

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: alarm_gas
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now, define a function for displaying a spectrogram:

# %%
def plot_spectrogram(spectrogram, ax):
  if len(spectrogram.shape) > 2:
    assert len(spectrogram.shape) == 3
    spectrogram = np.squeeze(spectrogram, axis=-1)
  # Convert the frequencies to log scale and transpose, so that the time is
  # represented on the x-axis (columns).
  # Add an epsilon to avoid taking a log of zero.
  log_spec = np.log(spectrogram.T + np.finfo(float).eps)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# Plot the example's waveform over time and the corresponding spectrogram (frequencies over time):

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now, define a function that transforms the waveform dataset into spectrograms and their corresponding labels as integer IDs:

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %% [markdown]
# Map `get_spectrogram_and_label_id` across the dataset's elements with `Dataset.map`:

# %%
spectrogram_ds = waveform_ds.map(
  map_func=get_spectrogram_and_label_id,
  num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Examine the spectrograms for different examples of the dataset:

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))

for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(spectrogram.numpy(), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')

plt.show()

# %% [markdown]
# ## Build and train the model
#
# Repeat the training set preprocessing on the validation and test sets:

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(
      map_func=get_waveform_and_label,
      num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(
      map_func=get_spectrogram_and_label_id,
      num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %% [markdown]
# Batch the training and validation sets for model training:

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Add `Dataset.cache` and `Dataset.prefetch` operations to reduce read latency while training the model:

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %% [markdown]
# For the model, you'll use a simple convolutional neural network (CNN), since you have transformed the audio files into spectrogram images.
#
# Your `tf.keras.Sequential` model will use the following Keras preprocessing layers:
#
# - `tf.keras.layers.Resizing`: to downsample the input to enable the model to train faster.
# - `tf.keras.layers.Normalization`: to normalize each pixel in the image based on its mean and standard deviation.
#
# For the `Normalization` layer, its `adapt` method would first need to be called on the training data in order to compute aggregate statistics (that is, the mean and the standard deviation).

# %%
for spectrogram, _ in spectrogram_ds.take(1):
  input_shape = spectrogram.shape
print('Input shape:', input_shape)
num_labels = len(commands)

# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    # Downsample the input.
    layers.Resizing(32, 32),
    # Normalize.
    norm_layer,
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels),
])

model.summary()
# Out:
# Input shape: (124, 129, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 32, 32, 1)         0
#
#  normalization (Normalizatio  (None, 32, 32, 1)        3
#  n)
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,625,224
# Trainable params: 1,625,221
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Configure the Keras model with the Adam optimizer and the cross-entropy loss:

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# Train the model over 10 epochs for demonstration purposes:

# %%
EPOCHS = 50
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS, verbose=1,
    
)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 28s 433ms/step - loss: 0.7064 - accuracy: 0.7642 - val_loss: 0.2483 - val_accuracy: 0.9400
# Epoch 2/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.2132 - accuracy: 0.9396 - val_loss: 0.1408 - val_accuracy: 0.9567
# Epoch 3/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.1329 - accuracy: 0.9596 - val_loss: 0.1181 - val_accuracy: 0.9700
# Epoch 4/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0972 - accuracy: 0.9683 - val_loss: 0.1017 - val_accuracy: 0.9700
# Epoch 5/50
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0810 - accuracy: 0.9758 - val_loss: 0.0991 - val_accuracy: 0.9733
# Epoch 6/50
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0688 - accuracy: 0.9808 - val_loss: 0.0875 - val_accuracy: 0.9733
# Epoch 7/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0482 - accuracy: 0.9850 - val_loss: 0.0829 - val_accuracy: 0.9733
# Epoch 8/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0404 - accuracy: 0.9871 - val_loss: 0.0940 - val_accuracy: 0.9767
# Epoch 9/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0345 - accuracy: 0.9904 - val_loss: 0.0844 - val_accuracy: 0.9800
# Epoch 10/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0280 - accuracy: 0.9925 - val_loss: 0.0781 - val_accuracy: 0.9867
# Epoch 11/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0260 - accuracy: 0.9925 - val_loss: 0.0680 - val_accuracy: 0.9867
# Epoch 12/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0603 - val_accuracy: 0.9900
# Epoch 13/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.0651 - val_accuracy: 0.9867
# Epoch 14/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0217 - accuracy: 0.9958 - val_loss: 0.0721 - val_accuracy: 0.9867
# Epoch 15/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.0528 - val_accuracy: 0.9867
# Epoch 16/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0183 - accuracy: 0.9954 - val_loss: 0.0585 - val_accuracy: 0.9833
# Epoch 17/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0201 - accuracy: 0.9950 - val_loss: 0.0645 - val_accuracy: 0.9800
# Epoch 18/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.0775 - val_accuracy: 0.9833
# Epoch 19/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.0761 - val_accuracy: 0.9867
# Epoch 20/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.0662 - val_accuracy: 0.9900
# Epoch 21/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0691 - val_accuracy: 0.9867
# Epoch 22/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0762 - val_accuracy: 0.9867
# Epoch 23/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.0744 - val_accuracy: 0.9900
# Epoch 24/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0758 - val_accuracy: 0.9900
# Epoch 25/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0146 - accuracy: 0.9962 - val_loss: 0.0707 - val_accuracy: 0.9867
# Epoch 26/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.0661 - val_accuracy: 0.9833
# Epoch 27/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0650 - val_accuracy: 0.9867
# Epoch 28/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0199 - accuracy: 0.9950 - val_loss: 0.0720 - val_accuracy: 0.9833
# Epoch 29/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0667 - val_accuracy: 0.9900
# Epoch 30/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0198 - accuracy: 0.9971 - val_loss: 0.0926 - val_accuracy: 0.9800
# Epoch 31/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0247 - accuracy: 0.9958 - val_loss: 0.0594 - val_accuracy: 0.9900
# Epoch 32/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9900
# Epoch 33/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9900
# Epoch 34/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0648 - val_accuracy: 0.9900
# Epoch 35/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0686 - val_accuracy: 0.9900
# Epoch 36/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0639 - val_accuracy: 0.9900
# Epoch 37/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0512 - val_accuracy: 0.9900
# Epoch 38/50
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0466 - val_accuracy: 0.9900
# Epoch 39/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0508 - val_accuracy: 0.9900
# Epoch 40/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0529 - val_accuracy: 0.9867
# Epoch 41/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.0638 - val_accuracy: 0.9867
# Epoch 42/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0471 - val_accuracy: 0.9900
# Epoch 43/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 0.0414 - val_accuracy: 0.9900
# Epoch 44/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0072 - accuracy: 0.9983 - val_loss: 0.0785 - val_accuracy: 0.9833
# Epoch 45/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.0591 - val_accuracy: 0.9900
# Epoch 46/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.0607 - val_accuracy: 0.9867
# Epoch 47/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0048 - accuracy: 0.9975 - val_loss: 0.0638 - val_accuracy: 0.9867
# Epoch 48/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0559 - val_accuracy: 0.9867
# Epoch 49/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0156 - accuracy: 0.9954 - val_loss: 0.0596 - val_accuracy: 0.9900
# Epoch 50/50
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0540 - val_accuracy: 0.9933

# %% [markdown]
# Let's plot the training and validation loss curves to check how your model has improved during training:

# %%
metrics = history.history
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %%
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
# final Accuracy and Loss
final_loss, final_acc = model.evaluate(val_ds, verbose=0)
print("Final loss: {0:.6f}, final accuracy: {1:.6f}".format(final_loss, final_acc))
# Out:
# Final loss: 0.053967, final accuracy: 0.993333

# %% [markdown]
# ## Evaluate the model performance
#
# Run the model on the test set and check the model's performance:

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 100%

# %% [markdown]
# ### Display a confusion matrix
#
# Use a <a href="https://developers.google.com/machine-learning/glossary#confusion-matrix" class="external">confusion matrix</a> to check how well the model did classifying each of the commands in the test set:

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %% [markdown]
# ## Run inference on an audio file
#
# Finally, verify the model's prediction output using an input audio file of someone saying "no". How well does your model perform?

# %%
import pandas as pd
import os
import librosa
import librosa.display
import numpy as np
import IPython.display as ipd
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

file_name='/content/drive/MyDrive/data/dataset-alarm-folder/testing/tsunami_alarm.tsunami_alarm_35.wav.2vgnpqm7.ingestion-59654888d4-frmkj.wav'


audio_data, sampling_rate = librosa.load(file_name)
librosa.display.waveplot(audio_data,sr=sampling_rate)
ipd.Audio(file_name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
TESTING_DIR = 'testing'
test_dir = pathlib.Path(TESTING_DIR)

# %%
sample_file = file_name
sample_ds = preprocess_dataset([str(sample_file)])

for spectrogram, label in sample_ds.batch(1):
  prediction = model(spectrogram)
  plt.bar(commands, tf.nn.softmax(prediction[0]))
  plt.title(f'Predictions for "{commands[label[0]]}"')
  plt.show()

# %% [markdown]
# As the output suggests, your model should have recognized the audio command as "alarm_danger".

# %%
# visualize model architecture
import visualkeras
from PIL import ImageFont
from tensorflow.keras.utils import plot_model

#plot model deep learning
plot_model(model, to_file="model-architecture.png", show_shapes=True)

# %%
from collections import defaultdict

color_map = defaultdict(dict)

visualkeras.layered_view(model, legend=True, color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=715x207 at 0x7EFC8D066290>

# %%
# Save the model to H5
model.save('saved_model.sav')
# Out:
# INFO:tensorflow:Assets written to: saved_model.sav/assets

# %%
# convert Model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_saved_model('saved_model.sav') # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('model_audio.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %% [markdown]
# Inference using TensorFlow Lite

# %%
# !pip install tflite-runtime
# Out:
# Collecting tflite-runtime
#   Downloading tflite_runtime-2.7.0-cp37-cp37m-manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 4.9 MB/s
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tflite-runtime) (1.21.5)
# Installing collected packages: tflite-runtime
# Successfully installed tflite-runtime-2.7.0

# %%
from tflite_runtime.interpreter import Interpreter
interpreter = Interpreter('model_audio.tflite')
interpreter.allocate_tensors()

# %%
interpreter.get_input_details()
# Out:
# [{'dtype': numpy.float32,
#   'index': 0,
#   'name': 'serving_default_input_1:0',
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'quantized_dimension': 0,
#    'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 124, 129,   1], dtype=int32),
#   'shape_signature': array([ -1, 124, 129,   1], dtype=int32),
#   'sparsity_parameters': {}}]

# %%
interpreter.get_output_details()
# Out:
# [{'dtype': numpy.float32,
#   'index': 17,
#   'name': 'StatefulPartitionedCall:0',
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'quantized_dimension': 0,
#    'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32)},
#   'shape': array([1, 5], dtype=int32),
#   'shape_signature': array([-1,  5], dtype=int32),
#   'sparsity_parameters': {}}]

# %% [markdown]
# So you can see that the input expected by the model is a tensor of shape (1, 129, 124,1) – the spectrogram which we used to train the model – and the expected output is (1, 5) – the five class alarm.
